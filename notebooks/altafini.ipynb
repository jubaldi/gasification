# %%
import os
import path_file
os.chdir(os.path.dirname(os.path.dirname(path_file.__file__)))
os.getcwd()
# Out:
# 'd:\\user\\Desktop\\Faculdade\\IC Rodolfo\\gasification 08-2023\\gasification'

# %%
import sys
import cantera as ct
import numpy as np
import scipy.optimize as opt
import matplotlib.pyplot as plt

import phases
import feedstock as fs
import fuel as fu
import energy as en
import gasifier as gs

# %%
ultimate = [52.00, 6.07, 41.55, 0.28, 0, 0]
ashDB = 0.10 / 100
HHV = 20.407 # MJ/kg

# %%
moistWB = 0.11
moistDB = moistWB / (1 - moistWB)
fuelDryMass = 11.7
fuel = fs.create_fuel_stream(fuelDryMass, ultimate, ashDB, moistDB, HHV)
fuelMass = fuel.get_mass()
print(fuelMass)
# Out:
# 13.146067415730336

# %%
AFR = 1.829
airMass = AFR * fuelMass
air = fs.create_air_stream(airMass)
outlet = gs.gasify_isot(fuel, air, T=832+273.15, P=0.93*1E5, charFormation=0.0, directMethaneConv=0.0)

species = ['CO', 'H2', 'CO2', 'CH4']
pure_model_frac = np.zeros(len(species))
pure_model_props = np.zeros(3)

for i, sp in enumerate(species):   
    pure_model_frac[i] = 100*outlet.get_syngas_fraction(sp, water=False, nitrogen=True)

pure_model_props[0] = outlet.get_syngas_hhv('vol', water=False, nitrogen=True)
pure_model_props[1] = outlet.get_syngas_amount(basis='mass', water=False, nitrogen=True) / fuelDryMass
pure_model_props[2] = outlet.get_syngas_CGE()
print(pure_model_props)
# Out:
# [6.07614684 3.01514027 0.84996294]

# %%
AFR = 1.829
airMass = AFR * fuelMass
air = fs.create_air_stream(airMass)
outlet = gs.gasify_isot(fuel, air, T=832+273.15, P=0.93*1E5, charFormation=0.15, directMethaneConv=0.0)

species = ['CO', 'H2', 'CO2', 'CH4']
char_model_frac = np.zeros(len(species))
char_model_props = np.zeros(3)

for i, sp in enumerate(species):   
    char_model_frac[i] = 100*outlet.get_syngas_fraction(sp, water=False, nitrogen=True)

char_model_props[0] = outlet.get_syngas_hhv('vol', water=False, nitrogen=True)
char_model_props[1] = outlet.get_syngas_amount(basis='mass', water=False, nitrogen=True) / fuelDryMass
char_model_props[2] = outlet.get_syngas_CGE()
print(char_model_props)
# Out:
# [5.21406143 2.86413513 0.66905323]

# %%
AFR = 1.829
airMass = AFR * fuelMass
air = fs.create_air_stream(airMass)
outlet = gs.gasify_isot(fuel, air, T=832+273.15, P=0.93*1E5, charFormation=0.15, directMethaneConv=0.05)

species = ['CO', 'H2', 'CO2', 'CH4']
both_model_frac = np.zeros(len(species))
both_model_props = np.zeros(3)

for i, sp in enumerate(species):
    both_model_frac[i] = 100*outlet.get_syngas_fraction(sp, water=False, nitrogen=True)

both_model_props[0] = outlet.get_syngas_hhv('vol', water=False, nitrogen=True)
both_model_props[1] = outlet.get_syngas_amount(basis='mass', water=False, nitrogen=True) / fuelDryMass
both_model_props[2] = outlet.get_syngas_CGE()
print(both_model_props)
# Out:
# [5.23074056 2.85272586 0.6427084 ]

# %%
frac_groups = ['$CO$', '$H_2$', '$CO_2$', '$CH_4$']
exp_frac = [20.14, 14.00, 12.06, 2.31]
author_model_frac = [19.70, 20.06, 10.15, 0]

X_axis1 = np.arange(len(frac_groups))

w = 0.15

fig, ax1 = plt.subplots(figsize=(8,5), dpi=100)
ax1.bar(X_axis1 - 2*w, exp_frac, w, label='Experimental', zorder=3)
ax1.bar(X_axis1 - w, author_model_frac, w, label='Model by Altafini et al.', zorder=3)
ax1.bar(X_axis1, pure_model_frac, w, label='Pure model', zorder=3)
ax1.bar(X_axis1 + w, char_model_frac, w, label='$f_{char}=0.15$', zorder=3)
ax1.bar(X_axis1 + 2*w, both_model_frac, w, label='$f_{char}=0.15, f_{methane}=0.05$', zorder=3)
ax1.set_ylabel("Syngas mole fraction (%)")
ax1.grid(zorder=0, axis='y')
ax1.set_ylim(0, 30)
plt.xticks(X_axis1, frac_groups)

plt.legend(loc='best')
plt.savefig('figures/altafini1.png')
plt.show()

# %%
prop_groups = ['HHV', 'Yield', 'CGE']
exp_props = [5.276, 31.89 / 11.7, 0.6286] # MJ/kg, kg syngas / kg fuel, CGE
author_model_props = [5.042, 33.96 / 12.60, 0.6799] # MJ/kg, kg syngas / kg fuel, CGE
  
X_axis2 = np.arange(3)

fig2, ax2 = plt.subplots(figsize=(6,5), dpi=100)
ax2.bar(X_axis2[:2] - 2*w, exp_props[:2], w, label='Experimental', zorder=3)
ax2.bar(X_axis2[:2] - w, author_model_props[:2], w, label='Model by Altafini et al.', zorder=3)
ax2.bar(X_axis2[:2], pure_model_props[:2], w, label='Pure model', zorder=3)
ax2.bar(X_axis2[:2] + w, char_model_props[:2], w, label='$f_{char}=0.15$', zorder=3)
ax2.bar(X_axis2[:2] + 2*w, both_model_props[:2], w, label='$f_{char}=0.15, f_{methane}=0.05$', zorder=3)
ax2.set_ylabel("Syngas HHV (MJ/Nm³) \n Syngas yield (kg/kg)")
ax2.set_ylim(0,10)

ax3 = ax2.twinx()
ax3.bar(X_axis2[2] - 2*w, 100*exp_props[2], w, label='Experimental', zorder=3)
ax3.bar(X_axis2[2] - w, 100*author_model_props[2], w, label='Model by Altafini et al.', zorder=3)
ax3.bar(X_axis2[2], 100*pure_model_props[2], w, label='Pure model', zorder=3)
ax3.bar(X_axis2[2] + w, 100*char_model_props[2], w, label='$f_{char}=0.15$', zorder=3)
ax3.bar(X_axis2[2] + 2*w, 100*both_model_props[2], w, label='$f_{char}=0.15, f_{methane}=0.05$', zorder=3)
ax3.set_ylabel("Cold gas efficiency, CGE (%)")
ax3.set_ylim(0,100)

plt.xticks(X_axis2, prop_groups)

ax2.grid(zorder=0, axis='y')
plt.legend(loc='best')
plt.savefig('figures/altafini2.png')
plt.show()
